# %%
from dotenv import load_dotenv
load_dotenv()
import os
import itertools
import random
from openai import OpenAI
from pinecone import Pinecone, ServerlessSpec

# %%
pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"))
pc.create_index(
    name="rag",
    dimension=100,
    metric="cosine",
    spec=ServerlessSpec(cloud="aws", region="us-east-1")
)

# %%
import json
data = json.load(open('reviews.json'))
data['reviews']
# Out:
# [{'professor': 'Dr. Emily Johnson',
#   'subject': 'Data Structures',
#   'stars': 5,
#   'review': 'Excellent professor! She made complex topics easy to understand.'},
#  {'professor': 'Dr. Mark Thompson',
#   'subject': 'Algorithms',
#   'stars': 4,
#   'review': 'Very knowledgeable, but his lectures can be a bit fast-paced.'},
#  {'professor': 'Dr. Sarah Lee',
#   'subject': 'Operating Systems',
#   'stars': 3,
#   'review': 'Solid professor, but sometimes the material was hard to follow.'},
#  {'professor': 'Dr. John Davis',
#   'subject': 'Database Systems',
#   'stars': 5,
#   'review': 'Great professor with a lot of real-world experience.'},
#  {'professor': 'Dr. Anna Smith',
#   'subject': 'Computer Networks',
#   'stars': 4,
#   'review': 'Good teacher, but the assignments were very challenging.'},
#  {'professor': 'Dr. Robert Brown',
#   'subject': 'Software Engineering',
#   'stars': 5,
#   'review': 'Amazing course! Dr. Brown is very engaging and helpful.'},
#  {'professor': 'Dr. Linda Wilson',
#   'subject': 'Artificial Intelligence',
#   'stars': 3,
#   'review': 'Interesting material, but the exams were tough.'},
#  {'professor': 'Dr. James Moore',
#   'subject': 'Machine Learning',
#   'stars': 4,
#   'review': 'Very insightful lectures, but the workload was heavy.'},
#  {'professor': 'Dr. Jessica Taylor',
#   'subject': 'Human-Computer Interaction',
#   'stars': 5,
#   'review': "One of the best professors I've had! Very interactive classes."},
#  {'professor': 'Dr. William Anderson',
#   'subject': 'Theory of Computation',
#   'stars': 2,
#   'review': 'Difficult to follow the lectures, and the material was confusing.'},
#  {'professor': 'Dr. Patricia Martin',
#   'subject': 'Cryptography',
#   'stars': 4,
#   'review': 'Challenging course, but Dr. Martin explains concepts clearly.'},
#  {'professor': 'Dr. Michael White',
#   'subject': 'Computer Graphics',
#   'stars': 3,
#   'review': 'Decent course, but the professor was not very engaging.'},
#  {'professor': 'Dr. Elizabeth Martinez',
#   'subject': 'Compiler Design',
#   'stars': 5,
#   'review': 'Fantastic course! Dr. Martinez is very supportive and knowledgeable.'},
#  {'professor': 'Dr. Christopher Thompson',
#   'subject': 'Parallel Computing',
#   'stars': 4,
#   'review': 'Very informative, but the projects were extremely difficult.'},
#  {'professor': 'Dr. Jennifer Lewis',
#   'subject': 'Natural Language Processing',
#   'stars': 5,
#   'review': 'Amazing professor! She made NLP fascinating and approachable.'},
#  {'professor': 'Dr. Richard Clark',
#   'subject': 'Discrete Mathematics',
#   'stars': 2,
#   'review': 'The lectures were dry, and the material was difficult to grasp.'},
#  {'professor': 'Dr. Donna Walker',
#   'subject': 'Cybersecurity',
#   'stars': 4,
#   'review': 'Good course, but the professor could have been more engaging.'},
#  {'professor': 'Dr. Andrew Harris',
#   'subject': 'Web Development',
#   'stars': 5,
#   'review': 'Fantastic course! Dr. Harris made web development fun and practical.'},
#  {'professor': 'Dr. Nancy King',
#   'subject': 'Mobile App Development',
#   'stars': 4,
#   'review': 'Great course, but the assignments were quite time-consuming.'},
#  {'professor': 'Dr. Steven Green',
#   'subject': 'Introduction to Programming',
#   'stars': 3,
#   'review': 'The professor was okay, but the course felt too basic.'}]

# %%
processed_data = []
client = OpenAI()

for review in data['reviews']:
    response = client.embeddings.create(
        input = review['review'],
        model="text-embedding-3-small",
    )
    embedding = response.data[0].embedding
    processed_data.append({
        "values":embedding,
        "id": review["professor"],
        "metadata": {
            "review": review["review"],
            "subject": review["subject"],
            "stars": review["stars"],
        }
    })

# %%
processed_data[0]
# Out:
# {'values': [0.000877183,
#   -0.038915027,
#   -0.05447122,
#   0.030719807,
#   0.0001925547,
#   -0.017187878,
#   -0.014893708,
#   0.045024637,
#   -0.0031100123,
#   -0.014672879,
#   0.029051319,
#   -0.00937911,
#   -0.0035884758,
#   -0.023677805,
#   0.0031590855,
#   0.0041252137,
#   -0.016648075,
#   0.011863439,
#   0.044313077,
#   0.03177488,
#   0.039896492,
#   -0.028707806,
#   0.023886368,
#   0.013421513,
#   -0.030351758,
#   -0.04816532,
#   0.030719807,
#   0.0045760735,
#   0.0048183724,
#   0.0082136225,
#   0.06948762,
#   -0.000100638346,
#   -0.007459122,
#   -0.042227466,
#   -0.026057854,
#   0.017678611,
#   -0.02551805,
#   0.0030210672,
#   -0.014488854,
#   0.013507391,
#   0.028045319,
#   0.010409647,
#   0.006606476,
#   0.03344337,
#   0.048582442,
#   0.020218147,
#   -0.04262005,
#   0.010618208,
#   0.03530815,
#   0.051281467,
#   -0.053882346,
#   0.009974123,
#   0.047478296,
#   0.04549083,
#   -0.08219757,
#   0.046864882,
#   0.02005866,
#   0.058789663,
#   -0.001380183,
#   -0.06830986,
#   0.039234,
#   -0.006143348,
#   0.03243737,
#   0.005713958,
#   -0.018451514,
#   -0.048140783,
#   -0.053538833,
#   -0.025419904,
#   -0.049981028,
#   -0.023334295,
#   0.04235015,
#   0.011023061,
#   -0.051526833,
#   -0.013703683,
#   -0.00014472753,
#   -0.021506319,
#   0.019310294,
#   -0.013384708,
#   -0.038228,
#   -0.023150269,
#   0.0014338568,
#   0.005698622,
#   0.022880368,
#   0.009078537,
#   -0.0017942379,
#   -0.004573006,
#   -0.005729293,
#   -0.00610961,
#   -0.013495123,
#   -0.04595703,
#   -0.029394832,
#   0.03601971,
#   -0.014341635,
#   -0.03636322,
#   0.0115567325,
#   -0.01962927,
#   -0.025616197,
#   0.04024,
#   -0.016684879,
#   -0.0026422837,
#   0.058053564,
#   -0.017862635,
#   0.031676732,
#   0.022757685,
#   0.051821273,
#   0.021763952,
#   -0.025150001,
#   -0.06801542,
#   -0.08111796,
#   -0.014991854,
#   -0.071843125,
#   -0.035627123,
#   0.00460061,
#   -0.018218415,
#   0.025861563,
#   -0.022009319,
#   -0.06649415,
#   -0.026990246,
#   -0.030180002,
#   -0.0098759765,
#   -0.0018509788,
#   -0.039724734,
#   0.03751644,
#   0.002677555,
#   -0.055698052,
#   -0.00052255264,
#   -0.029836489,
#   0.030891562,
#   -0.0054133846,
#   0.04514732,
#   -0.016979318,
#   -0.02883049,
#   -0.008281098,
#   -0.013458318,
#   -0.0026330824,
#   -0.019727416,
#   0.00093085674,
#   -0.010839038,
#   -0.036338683,
#   -0.007121744,
#   -0.021960245,
#   0.001360247,
#   -0.01875822,
#   -0.013458318,
#   -0.0005842775,
#   0.010593671,
#   0.027996246,
#   -0.0032572318,
#   0.01818161,
#   -0.018586464,
#   -0.008802501,
#   -0.0039442563,
#   -0.0061678845,
#   -0.003428988,
#   1.2430033e-06,
#   -0.024193075,
#   -0.005220159,
#   -0.019653806,
#   -0.010066135,
#   -0.021101465,
#   0.050226394,
#   0.0058795796,
#   -0.01747005,
#   -0.0034995307,
#   0.025787953,
#   0.0086246105,
#   0.0062537626,
#   0.007281232,
#   0.00274043,
#   0.025640734,
#   0.03952844,
#   0.0030762746,
#   -0.03229015,
#   0.028855026,
#   0.00081660826,
#   -0.015016391,
#   0.012403245,
#   0.052066635,
#   -0.013691415,
#   0.009415915,
#   0.02077022,
#   0.015016391,
#   0.011722354,
#   0.02703932,
#   -0.02723561,
#   -0.02128549,
#   0.0074407198,
#   0.0032848355,
#   0.01804666,
#   -0.012709952,
#   -0.017028391,
#   -0.019101733,
#   -0.016746221,
#   -0.016721684,
#   -0.005845842,
#   0.016194148,
#   -0.018414708,
#   0.025763417,
#   0.0072873663,
#   0.0048429086,
#   -0.042374685,
#   -0.027922636,
#   -0.0044871285,
#   0.018463781,
#   -0.016120538,
#   -0.008176818,
#   0.02005866,
#   0.0517722,
#   0.0062169577,
#   0.015678879,
#   0.06600342,
#   -0.048189856,
#   0.0057170247,
#   -0.0007683019,
#   0.020009587,
#   0.016255489,
#   -0.030327221,
#   0.01804666,
#   -0.001085744,
#   -0.0069131833,
#   -0.033516977,
#   -0.03359059,
#   -0.021187343,
#   0.024634734,
#   -0.014157611,
#   -0.010888111,
#   -5.2715324e-05,
#   0.011544464,
#   -0.008244293,
#   -0.0109310495,
#   -0.026131464,
#   -0.01983783,
#   0.023432441,
#   -0.015703415,
#   0.013715952,
#   -0.060212784,
#   -0.03386049,
#   -0.036191467,
#   -0.02573888,
#   -0.027996246,
#   -0.01071022,
#   -0.014218952,
#   -0.056483224,
#   -0.027137466,
#   0.02711293,
#   -0.022831295,
#   -0.041442294,
#   -0.020328563,
#   0.010943318,
#   0.021027856,
#   -0.0021070794,
#   0.009293232,
#   0.0041160122,
#   -0.0025901434,
#   0.032216538,
#   0.016292294,
#   0.011464721,
#   0.018672343,
#   -0.025064124,
#   -0.012550464,
#   -0.018709147,
#   -0.012893977,
#   -0.0053643114,
#   0.016905708,
#   -0.040141854,
#   0.01322522,
#   -0.021076929,
#   0.0043767137,
#   -0.03984742,
#   0.015985586,
#   -0.020892903,
#   -0.00618322,
#   -0.0019491251,
#   0.019813294,
#   -0.004508598,
#   -0.023407904,
#   0.021935709,
#   0.020647537,
#   0.017420977,
#   0.055256393,
#   0.00643472,
#   -0.001098779,
#   -0.0031621526,
#   -0.036216002,
#   -0.018537391,
#   0.016611269,
#   0.0008327104,
#   0.027211076,
#   0.008262696,
#   0.0010435717,
#   0.011912513,
#   -0.023972245,
#   -0.013605538,
#   0.019604733,
#   -0.009342305,
#   0.0111273425,
#   0.019150807,
#   0.0070726713,
#   -0.022512319,
#   0.00334311,
#   -0.035995174,
#   0.0067475615,
#   -0.008048001,
#   -0.043184392,
#   -0.008090939,
#   -0.009489525,
#   0.020978782,
#   0.005882647,
#   0.008281098,
#   -0.010483257,
#   0.011458586,
#   -0.010642745,
#   0.0012237623,
#   -0.017310562,
#   -0.022806758,
#   -0.003839976,
#   0.053097174,
#   0.0028922502,
#   0.005775299,
#   0.026474977,
#   0.023555124,
#   -0.020304026,
#   0.022230148,
#   -0.01042805,
#   0.008692086,
#   0.02078249,
#   0.0042847013,
#   -0.024144001,
#   0.003726494,
#   0.0084283175,
#   0.029492978,
#   0.012378708,
#   0.036044247,
#   0.008452854,
#   0.03651044,
#   0.021444976,
#   0.032461904,
#   -0.0019092532,
#   0.0045914087,
#   -0.0048306407,
#   0.010244025,
#   0.037540976,
#   -0.025248148,
#   0.00064331864,
#   -0.007275098,
#   -0.028315222,
#   -0.021555392,
#   -0.01890544,
#   -0.016942512,
#   0.001651619,
#   -0.07768283,
#   -0.021739416,
#   -0.0019353232,
#   0.009047867,
#   0.044092245,
#   0.03226561,
#   0.014930513,
#   -0.028437903,
#   -0.0005524566,
#   -0.013507391,
#   -0.008324037,
#   -0.0121640125,
#   0.031235075,
#   0.007103342,
#   0.016108269,
#   0.0015964117,
#   -0.014685147,
#   -0.025689807,
#   0.017286025,
#   -0.008735025,
#   0.013789562,
#   0.01883183,
#   -0.01918761,
#   0.015114537,
#   0.0047754333,
#   0.008048001,
#   0.015666611,
#   -0.02134683,
#   -0.026474977,
#   -0.038277075,
#   -0.040141854,
#   -0.03285449,
#   ...],
#  'id': 'Dr. Emily Johnson',
#  'metadata': {'review': 'Excellent professor! She made complex topics easy to understand.',
#   'subject': 'Data Structures',
#   'stars': 5}}

# %%
index = pc.Index('rag')
def chunks(iterable, batch_size=100):
    """A helper function to break an iterable into chunks of size batch_size."""
    it = iter(iterable)
    chunk = tuple(itertools.islice(it, batch_size))
    while chunk:
        yield chunk
        chunk = tuple(itertools.islice(it, batch_size))
vector_dim = 100
vector_count = 20

# Example generator that generates many (id, vector) pairs
example_data_generator = map(lambda i: (f'id-{i}', [random.random() for _ in range(vector_dim)]), range(vector_count))

# Upsert data with 100 vectors per upsert request
for ids_vectors_chunk in chunks(example_data_generator, batch_size=200):
    index.upsert(vectors=ids_vectors_chunk, namespace='ns1')

# %%
index.describe_index_stats()
# Out:
# {'dimension': 100,
#  'index_fullness': 0.0,
#  'namespaces': {'ns1': {'vector_count': 10200}},
#  'total_vector_count': 10200}
